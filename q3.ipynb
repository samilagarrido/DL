# %%
import matplotlib.pyplot as plt
import numpy as np
from random import uniform
from shapely.geometry import Point, Polygon
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import itertools

# %%
class CreateData:
    def __init__(self, points=500):
        self.points = points

    def random_points(self, poly):
        minx, miny, maxx, maxy = poly.bounds
        while True:
            p = Point(uniform(minx, maxx), uniform(miny, maxy))
            if poly.contains(p):
                return p

    def polar_point(self, origin_point, angle,  distance):
        return [origin_point.x + math.sin(math.radians(angle)) * distance, origin_point.y + math.cos(math.radians(angle)) * distance]

    def sector(self, center, start_angle, end_angle, radius, steps=200):
        step_angle_width = (end_angle-start_angle) / steps
        sector_width = (end_angle-start_angle) 
        segment_vertices = []

        segment_vertices.append(self.polar_point(center, 0,0))
        segment_vertices.append(self.polar_point(center, start_angle,radius))

        for i in range(1, steps):
            segment_vertices.append((self.polar_point(center, start_angle + i * step_angle_width,radius)))
        segment_vertices.append(self.polar_point(center, start_angle+sector_width,radius))
        segment_vertices.append(self.polar_point(center, 0,0))
        return Polygon(segment_vertices)

    def create_samples_labels(self):
        polygons = [Polygon([(0, 0), (1, 0), (0, 1), (0, 0)]), Polygon([(0, 0), (-1, 0), (0, 1), (0, 0)]), 
                    Polygon([(0, 0), (-1, 0), (0, -1), (0, 0)]), Polygon([(0, 0), (1, 0), (0, -1), (0, 0)])]
        polygon_points = [[] for _ in polygons]

        for i in range(self.points):
            for j in range(len(polygons)):
                polygon_points[j].append(self.random_points(polygons[j]))

        center = Point(0,0)
        sectors = [self.sector(center, 0, 90, 1), self.sector(center, 0, -90, 1), self.sector(center, 180, 270, 1), self.sector(center, 180, 90, 1)]
        sector_points = [[] for _ in sectors]

        for i in range(self.points):
            for j in range(len(sectors)):
                sector_points[j].append(self.random_points(sectors[j].difference(polygons[j])))

        samples = []
        labels = []

        for i in range(self.points):
            for j in range(len(polygons)):
                samples.append([polygon_points[j][i].x, polygon_points[j][i].y])
                labels.append([int(k==j) for k in range(len(polygons))])
            for j in range(len(sectors)):
                samples.append([sector_points[j][i].x, sector_points[j][i].y])
                labels.append([int(k==j+len(polygons)) for k in range(len(polygons)+len(sectors))])

        max_sample_length = max(len(sample) for sample in samples)
        max_label_length = max(len(label) for label in labels)

        samples = [sample + [0]*(max_sample_length - len(sample)) for sample in samples]
        labels = [label + [0]*(max_label_length - len(label)) for label in labels]

        return np.array(samples), np.array(labels)

# %%
generator = CreateData(points=500)
samples, labels = generator.create_samples_labels()

# %%
train_samples, test_samples, train_labels, test_labels = train_test_split(samples, labels, test_size=0.2, random_state=45)

# %%
train_samples.shape
train_labels.shape
# Out:
# (3200, 8)

# %%
model = Sequential([
    Dense(units=16, input_shape=(2,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=8, activation='softmax'),
])

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
result = model.fit(x=train_samples, y=train_labels, validation_split=0.1, batch_size=22, epochs=50, shuffle=True, verbose=2)
# Out:
# Epoch 1/50
# 131/131 - 1s - loss: 0.8707 - accuracy: 0.6309 - val_loss: 0.4594 - val_accuracy: 0.8156 - 936ms/epoch - 7ms/step
# Epoch 2/50
# 131/131 - 0s - loss: 0.3624 - accuracy: 0.8576 - val_loss: 0.2918 - val_accuracy: 0.8938 - 199ms/epoch - 2ms/step
# Epoch 3/50
# 131/131 - 0s - loss: 0.2708 - accuracy: 0.8896 - val_loss: 0.2207 - val_accuracy: 0.9094 - 179ms/epoch - 1ms/step
# Epoch 4/50
# 131/131 - 0s - loss: 0.1998 - accuracy: 0.9285 - val_loss: 0.1901 - val_accuracy: 0.9187 - 153ms/epoch - 1ms/step
# Epoch 5/50
# 131/131 - 0s - loss: 0.1820 - accuracy: 0.9281 - val_loss: 0.2278 - val_accuracy: 0.8969 - 168ms/epoch - 1ms/step
# Epoch 6/50
# 131/131 - 0s - loss: 0.1822 - accuracy: 0.9278 - val_loss: 0.1708 - val_accuracy: 0.9344 - 195ms/epoch - 1ms/step
# Epoch 7/50
# 131/131 - 0s - loss: 0.1730 - accuracy: 0.9285 - val_loss: 0.1816 - val_accuracy: 0.9312 - 248ms/epoch - 2ms/step
# Epoch 8/50
# 131/131 - 0s - loss: 0.1651 - accuracy: 0.9316 - val_loss: 0.1522 - val_accuracy: 0.9375 - 177ms/epoch - 1ms/step
# Epoch 9/50
# 131/131 - 0s - loss: 0.1307 - accuracy: 0.9486 - val_loss: 0.1194 - val_accuracy: 0.9531 - 160ms/epoch - 1ms/step
# Epoch 10/50
# 131/131 - 0s - loss: 0.1758 - accuracy: 0.9281 - val_loss: 0.1999 - val_accuracy: 0.9125 - 179ms/epoch - 1ms/step
# Epoch 11/50
# 131/131 - 0s - loss: 0.1821 - accuracy: 0.9208 - val_loss: 0.1629 - val_accuracy: 0.9406 - 175ms/epoch - 1ms/step
# Epoch 12/50
# 131/131 - 0s - loss: 0.1475 - accuracy: 0.9372 - val_loss: 0.1943 - val_accuracy: 0.9156 - 191ms/epoch - 1ms/step
# Epoch 13/50
# 131/131 - 0s - loss: 0.1159 - accuracy: 0.9569 - val_loss: 0.1626 - val_accuracy: 0.9281 - 207ms/epoch - 2ms/step
# Epoch 14/50
# 131/131 - 0s - loss: 0.1402 - accuracy: 0.9396 - val_loss: 0.1321 - val_accuracy: 0.9406 - 206ms/epoch - 2ms/step
# Epoch 15/50
# 131/131 - 0s - loss: 0.1256 - accuracy: 0.9500 - val_loss: 0.1319 - val_accuracy: 0.9438 - 233ms/epoch - 2ms/step
# Epoch 16/50
# 131/131 - 0s - loss: 0.1488 - accuracy: 0.9382 - val_loss: 0.0967 - val_accuracy: 0.9625 - 206ms/epoch - 2ms/step
# Epoch 17/50
# 131/131 - 0s - loss: 0.1475 - accuracy: 0.9375 - val_loss: 0.1386 - val_accuracy: 0.9375 - 207ms/epoch - 2ms/step
# Epoch 18/50
# 131/131 - 0s - loss: 0.1559 - accuracy: 0.9378 - val_loss: 0.1886 - val_accuracy: 0.9250 - 189ms/epoch - 1ms/step
# Epoch 19/50
# 131/131 - 0s - loss: 0.1121 - accuracy: 0.9517 - val_loss: 0.0913 - val_accuracy: 0.9688 - 196ms/epoch - 1ms/step
# Epoch 20/50
# 131/131 - 0s - loss: 0.1161 - accuracy: 0.9503 - val_loss: 0.1802 - val_accuracy: 0.9281 - 158ms/epoch - 1ms/step
# Epoch 21/50
# 131/131 - 0s - loss: 0.1288 - accuracy: 0.9465 - val_loss: 0.1038 - val_accuracy: 0.9500 - 166ms/epoch - 1ms/step
# Epoch 22/50
# 131/131 - 0s - loss: 0.1155 - accuracy: 0.9486 - val_loss: 0.0853 - val_accuracy: 0.9656 - 165ms/epoch - 1ms/step
# Epoch 23/50
# 131/131 - 0s - loss: 0.1195 - accuracy: 0.9552 - val_loss: 0.0921 - val_accuracy: 0.9656 - 169ms/epoch - 1ms/step
# Epoch 24/50
# 131/131 - 0s - loss: 0.1120 - accuracy: 0.9503 - val_loss: 0.1111 - val_accuracy: 0.9531 - 294ms/epoch - 2ms/step
# Epoch 25/50
# 131/131 - 0s - loss: 0.1174 - accuracy: 0.9503 - val_loss: 0.0956 - val_accuracy: 0.9594 - 208ms/epoch - 2ms/step
# Epoch 26/50
# 131/131 - 0s - loss: 0.0891 - accuracy: 0.9642 - val_loss: 0.0975 - val_accuracy: 0.9469 - 217ms/epoch - 2ms/step
# Epoch 27/50
# 131/131 - 0s - loss: 0.0872 - accuracy: 0.9667 - val_loss: 0.1556 - val_accuracy: 0.9344 - 180ms/epoch - 1ms/step
# Epoch 28/50
# 131/131 - 0s - loss: 0.1185 - accuracy: 0.9528 - val_loss: 0.2018 - val_accuracy: 0.9375 - 207ms/epoch - 2ms/step
# Epoch 29/50
# 131/131 - 0s - loss: 0.1156 - accuracy: 0.9524 - val_loss: 0.0909 - val_accuracy: 0.9594 - 160ms/epoch - 1ms/step
# Epoch 30/50
# 131/131 - 0s - loss: 0.0956 - accuracy: 0.9642 - val_loss: 0.1007 - val_accuracy: 0.9531 - 183ms/epoch - 1ms/step
# Epoch 31/50
# 131/131 - 0s - loss: 0.1062 - accuracy: 0.9545 - val_loss: 0.1662 - val_accuracy: 0.9344 - 164ms/epoch - 1ms/step
# Epoch 32/50
# 131/131 - 0s - loss: 0.1212 - accuracy: 0.9486 - val_loss: 0.2477 - val_accuracy: 0.9125 - 193ms/epoch - 1ms/step
# Epoch 33/50
# 131/131 - 0s - loss: 0.1359 - accuracy: 0.9434 - val_loss: 0.0951 - val_accuracy: 0.9500 - 149ms/epoch - 1ms/step
# Epoch 34/50
# 131/131 - 0s - loss: 0.1094 - accuracy: 0.9552 - val_loss: 0.1426 - val_accuracy: 0.9406 - 156ms/epoch - 1ms/step
# Epoch 35/50
# 131/131 - 0s - loss: 0.1003 - accuracy: 0.9563 - val_loss: 0.0884 - val_accuracy: 0.9688 - 157ms/epoch - 1ms/step
# Epoch 36/50
# 131/131 - 0s - loss: 0.1057 - accuracy: 0.9573 - val_loss: 0.1610 - val_accuracy: 0.9219 - 178ms/epoch - 1ms/step
# Epoch 37/50
# 131/131 - 0s - loss: 0.1077 - accuracy: 0.9556 - val_loss: 0.1189 - val_accuracy: 0.9406 - 172ms/epoch - 1ms/step
# Epoch 38/50
# 131/131 - 0s - loss: 0.1059 - accuracy: 0.9563 - val_loss: 0.0898 - val_accuracy: 0.9531 - 180ms/epoch - 1ms/step
# Epoch 39/50
# 131/131 - 0s - loss: 0.0994 - accuracy: 0.9573 - val_loss: 0.0991 - val_accuracy: 0.9625 - 172ms/epoch - 1ms/step
# Epoch 40/50
# 131/131 - 0s - loss: 0.0749 - accuracy: 0.9698 - val_loss: 0.0888 - val_accuracy: 0.9594 - 179ms/epoch - 1ms/step
# Epoch 41/50
# 131/131 - 0s - loss: 0.1170 - accuracy: 0.9531 - val_loss: 0.1554 - val_accuracy: 0.9375 - 195ms/epoch - 1ms/step
# Epoch 42/50
# 131/131 - 0s - loss: 0.1044 - accuracy: 0.9608 - val_loss: 0.1191 - val_accuracy: 0.9375 - 150ms/epoch - 1ms/step
# Epoch 43/50
# 131/131 - 0s - loss: 0.1062 - accuracy: 0.9563 - val_loss: 0.1312 - val_accuracy: 0.9469 - 187ms/epoch - 1ms/step
# Epoch 44/50
# 131/131 - 0s - loss: 0.0854 - accuracy: 0.9670 - val_loss: 0.1057 - val_accuracy: 0.9531 - 206ms/epoch - 2ms/step
# Epoch 45/50
# 131/131 - 0s - loss: 0.0928 - accuracy: 0.9601 - val_loss: 0.0917 - val_accuracy: 0.9625 - 173ms/epoch - 1ms/step
# Epoch 46/50
# 131/131 - 0s - loss: 0.0864 - accuracy: 0.9674 - val_loss: 0.1426 - val_accuracy: 0.9438 - 162ms/epoch - 1ms/step
# Epoch 47/50
# 131/131 - 0s - loss: 0.0940 - accuracy: 0.9580 - val_loss: 0.1032 - val_accuracy: 0.9469 - 169ms/epoch - 1ms/step
# Epoch 48/50
# 131/131 - 0s - loss: 0.1008 - accuracy: 0.9566 - val_loss: 0.0654 - val_accuracy: 0.9688 - 212ms/epoch - 2ms/step
# Epoch 49/50
# 131/131 - 0s - loss: 0.0742 - accuracy: 0.9698 - val_loss: 0.0892 - val_accuracy: 0.9563 - 301ms/epoch - 2ms/step
# Epoch 50/50
# 131/131 - 0s - loss: 0.0972 - accuracy: 0.9587 - val_loss: 0.1548 - val_accuracy: 0.9312 - 284ms/epoch - 2ms/step

# %%
plt.plot(result.history['loss'], label='loss')
plt.plot(result.history['val_loss'], label='val_loss')
plt.legend()

# %%
predictions = model.predict(x=test_samples, batch_size=22,verbose=0)

# %%
rounded_predictions = np.argmax(predictions, axis=-1)

# %%
accuracy_score(rounded_predictions, np.argmax(test_labels, axis=-1))
# Out:
# 0.92625

# %% [markdown]
# # Matriz de Confusão

# %%
cm = confusion_matrix(np.argmax(test_labels, axis=-1), rounded_predictions)

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

cm_plot_labels = ['1', '2', '3', '4', '5', '6', '7', '8']
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')

plt.show()
